# %% [markdown]
# # 마크다운 연습기
# -----
# 마크다운을 사용하면서 주피터 노트북과 친해져보겠습니다.
# 이 링크를 누르면 [코알라](http://coalastudy.com/)로 이동하세요.
#
# 여기서부터는 다른분단입니다.
#
# -----

# %% [markdown]
# ## 지금까지 배운내용
# 마크다운으로 배운 내용
# 1. 큰 제목 넣기
# 1. 리스트 넣기
# 1. 표 넣기
# 1. 기타
# ---

# %% [markdown]
# ## 정리
#
# 문법|사용법
# -|-
# 큰 제목|#을 사용
# 리스트|- 혹은 1. 사용

# %% [markdown]
# ## 마무리
# 파이썬 코드로 Hello World!를 만들면서 끝내요.
# ```python
# print("Hello World!')
# ```

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ---
# ## 제작자
# **작성자** 배진우
# ![이미지](data:image/jpeg;base64,...)
