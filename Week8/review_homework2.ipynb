# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set()

# %%
train = pd.read_csv('data/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
maleSurv = train.loc[(train['Sex']=='male') &
                    (train['Age']>=40.0) &
                    (train['Survived']==1),'PassengerId'].count()
femaleSurv = train.loc[(train['Sex']=='female') &
                    (train['Age']>=40.0) &
                    (train['Survived']==1),'PassengerId'].count()
maleDie = train.loc[(train['Sex']=='male') &
                    (train['Age']>=40.0) &
                    (train['Survived']==0),'PassengerId'].count()
femaleDie = train.loc[(train['Sex']=='female') &
                    (train['Age']>=40.0) &
                    (train['Survived']==0),'PassengerId'].count()

print(maleSurv, femaleSurv, maleDie, femaleDie)

df = pd.DataFrame({
    'male': [maleDie, maleSurv],
    'female':[femaleDie,femaleSurv]
})
df
# Out:
# 19 42 90 12
#    male  female
# 0    90      12
# 1    19      42

# %%
sns.countplot('SibSp', hue = 'Survived', data = train)

# %%
sns.catplot(data=train,x='SibSp',hue='Survived',kind='count')
