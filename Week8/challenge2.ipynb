# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import pandas as pd
train = pd.read_csv('data/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
deadCount = train.loc[train['Survived']==0,'PassengerId'].count()
surviveCount = train.loc[train['Survived']==1,'PassengerId'].count()
print(deadCount)
print(surviveCount)

# 1단계
plt.bar([0,1],[deadCount,surviveCount])
plt.show()
# Out:
# 549
# 342

# %%
# 2단계
plt.bar(['0'],[deadCount],color = 'blue',width=0.5)
plt.bar(['1'],[surviveCount],color = 'red',width=0.5)
plt.ylabel('count')
plt.xlabel('Survived')
plt.legend(['Dead','Survived'])
plt.show()
